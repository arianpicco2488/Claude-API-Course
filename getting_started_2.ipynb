# %% [markdown]
# # Accessing Claude with the API
#
# Course: [Claude with the Anthropic API](https://anthropic.skilljar.com/claude-with-the-anthropic-api/287725)

# %% [markdown]
# ## Setup

# %%
# %pip install anthropic python-dotenv
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: anthropic in /Users/ArianPicco/Library/Python/3.9/lib/python/site-packages (0.117.0)
# Requirement already satisfied: python-dotenv in /Users/ArianPicco/Library/Python/3.9/lib/python/site-packages (1.2.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/ArianPicco/Library/Python/3.9/lib/python/site-packages (from anthropic) (0.16.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/ArianPicco/Library/Python/3.9/lib/python/site-packages (from anthropic) (1.9.0)
# Requirement already satisfied: typing-extensions<5,>=4.14 in /Users/ArianPicco/Library/Python/3.9/lib/python/site-packages (from anthropic) (4.16.0)
# Requirement already satisfied: sniffio in /Users/ArianPicco/Library/Python/3.9/lib/python/site-packages (from anthropic) (1.3.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/ArianPicco/Library/Python/3.9/lib/python/site-packages (from anthropic) (2.13.4)
# Requirement already satisfied: docstring-parser<1,>=0.15 in /Users/ArianPicco/Library/Python/3.9/lib/python/site-packages (from anthropic) (0.18.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in /Users/ArianPicco/Library/Python/3.9/lib/python/site-packages (from anthropic) (0.28.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/ArianPicco/Library/Python/3.9/lib/python/site-packages (from anthropic) (4.12.1)
# Requirement already satisfied: idna>=2.8 in /Users/ArianPicco/Library/Python/3.9/lib/python/site-packages (from anyio<5,>=3.5.0->anthropic) (3.18)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/ArianPicco/Library/Python/3.9/lib/python/site-packages (from anyio<5,>=3.5.0->anthropic) (1.3.1)
# Requirement already satisfied: httpcore==1.* in /Users/ArianPicco/Library/Python/3.9/lib/python/site-packages (from httpx<1,>=0.25.0->anthropic) (1.0.9)
# Requirement already satisfied: certifi in /Users/ArianPicco/Library/Python/3.9/lib/python/site-packages (from httpx<1,>=0.25.0->anthropic) (2026.6.17)
# Requirement already satisfied: h11>=0.16 in /Users/ArianPicco/Library/Python/3.9/lib/python/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic) (0.16.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/ArianPicco/Library/Python/3.9/lib/python/site-packages (from pydantic<3,>=1.9.0->anthropic) (0.4.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/ArianPicco/Library/Python/3.9/lib/python/site-packages (from pydantic<3,>=1.9.0->anthropic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /Users/ArianPicco/Library/Python/3.9/lib/python/site-packages (from pydantic<3,>=1.9.0->anthropic) (2.46.4)
# WARNING: You are using pip version 21.2.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# ## Making a request

# %%
from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-4-5-20250929"

# %%
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)
    
def chat(messages, system=None, temperature=1.0, stop_sequences=None):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature
    }
    if system:
        params["system"] = system
    if stop_sequences:
        params["stop_sequences"] = stop_sequences

    message = client.messages.create(**params)
    for block in message.content:
        if block.type == "text":
            return block.text

message = client.messages.create(
    model=model,
    max_tokens=1000,
    messages=[
        {
            "role": "user",
            "content": "Write another sentence"
        }
    ]
)
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[4], line 26
#      23         if block.type == "text":
#      24             return block.text
# ---> 26 message = client.messages.create(
#      27     model=model,
#      28     max_tokens=1000,
#      29     messages=[
#      30         {
#      31             "role": "user",
#      32             "content": "Write another sentence"
#      33         }
#      34     ]
#      35 )
#
# File ~/Library/Python/3.9/lib/python/site-packages/anthropic/_utils/_utils.py:294, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     292             msg = f"Missing required argument: {quote(missing[0])}"
#     293     raise TypeError(msg)
# --> 294 return func(*args, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/anthropic/resources/messages/messages.py:1050, in Messages.create(self, max_tokens, messages, model, cache_control, container, inference_geo, metadata, output_config, service_tier, stop_sequences, stream, system, temperature, thinking, tool_choice, tools, top_k, top_p, user_profile_id, extra_headers, extra_query, extra_body, timeout)
#    1043     warnings.warn(
#    1044         f"Using Claude with {model} and 'thinking.type=enabled' is deprecated. Use 'thinking.type=adaptive' instead which results in better model performance in our testing: https://platform.claude.com/docs/en/build-with-claude/adaptive-thinking",
#    1045         UserWarning,
#    1046         stacklevel=3,
#    1047     )
#    1049 extra_headers = {**strip_not_given({"anthropic-user-profile-id": user_profile_id}), **(extra_headers or {})}
# -> 1050 return self._post(
#    1051     "/v1/messages",
#    1052     body=maybe_transform(
#    1053         {
#    1054             "max_tokens": max_tokens,
#    1055             "messages": messages,
#    1056             "model": model,
#    1057             "cache_control": cache_control,
#    1058             "container": container,
#    1059             "inference_geo": inference_geo,
#    1060             "metadata": metadata,
#    1061             "output_config": output_config,
#    1062             "service_tier": service_tier,
#    1063             "stop_sequences": stop_sequences,
#    1064             "stream": stream,
#    1065             "system": system,
#    1066             "temperature": temperature,
#    1067             "thinking": thinking,
#    1068             "tool_choice": tool_choice,
#    1069             "tools": tools,
#    1070             "top_k": top_k,
#    1071             "top_p": top_p,
#    1072         },
#    1073         message_create_params.MessageCreateParamsStreaming
#    1074         if stream
#    1075         else message_create_params.MessageCreateParamsNonStreaming,
#    1076     ),
#    1077     options=make_request_options(
#    1078         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1079     ),
#    1080     cast_to=Message,
#    1081     stream=stream or False,
#    1082     stream_cls=Stream[RawMessageStreamEvent],
#    1083 )
#
# File ~/Library/Python/3.9/lib/python/site-packages/anthropic/_base_client.py:1536, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1527     warnings.warn(
#    1528         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1529         "Please pass raw bytes via the `content` parameter instead.",
#    1530         DeprecationWarning,
#    1531         stacklevel=2,
#    1532     )
#    1533 opts = FinalRequestOptions.construct(
#    1534     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1535 )
# -> 1536 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/Library/Python/3.9/lib/python/site-packages/anthropic/_base_client.py:1195, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1192     if not response.is_closed:
#    1193         response.read()
# -> 1195     raise self._make_status_error_from_response(response) from None
#    1197 raise RuntimeError("could not resolve response (should never happen)")
#
# AuthenticationError: Error code: 401 - {'type': 'error', 'error': {'type': 'authentication_error', 'message': 'API key is invalid.'}, 'request_id': None}

# %%
messages = []
add_user_message(messages, "Generate a very short event bridge rule as json")   
add_assistant_message(messages, "```json")
chat(messages,stop_sequences=["```"])
text = chat(messages, stop_sequences=["```"])

# %%
import json

json.loads(text.strip())

# %% [markdown]
# prompt = f"""
# Please answer the user's question:
#
# {question}
# """
